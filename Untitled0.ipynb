# %%
# Pelatihan minggu pertama 1
print('Nama           : Bagus Mukhamad Muslim')
print('\nNPM            : 2420506046')
print('\nAlamat         : Jl.Kyai Mojo, Gang Cacaban, Magelang Tengah ')
print('\nTinggi Badan   : 165')
print('\nBerat Badan    : 50.2')
# Out:
# Nama           : Bagus Mukhamad Muslim
#
# NPM            : 2420506046
#
# Alamat         : Jl.Kyai Mojo, Gang Cacaban, Magelang Tengah
#
# Tinggi Badan   : 165
#
# Berat Badan    : 50.2

# %%
#Pelatihan minggu pertama 2
print('\033[1mUNIVERSITAS TIDAR\033[0m')

print('Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri \nyang telah ditetapkan Peraturan Presiden Replublik Indonesia Nomor23 Tahun 2014 pada tanggal 1 April 2014.')

print('\n\n\033[1mJURUSAN TEKNIK ELEKTRO, MEKATRONIKA, DAN INFORMASI\033[0m')

print('Jurusan Teknik Elektro terdiri atas tiga program studi, antara lain:')

print('   1. S1 Teknik Elektro \x1b[3m(Bachelor of Electrical Engineering)\x1b[0m')

print('   2. S1 Teknologi Informasi \x1b[3m(Bachelor of Information Technology)\x1b[0m')

print('   3. S1 Teknik Mekatronika \x1b[3m(Bachelor of Mechatronics Engineering)\x1b[0m')
# Out:
# UNIVERSITAS TIDAR
# Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi Negeri
# yang telah ditetapkan Peraturan Presiden Replublik Indonesia Nomor23 Tahun 2014 pada tanggal 1 April 2014
#
#
# JURUSAN TEKNIK ELEKTRO, MEKATRONIKA, DAN INFORMASI
# Jurusan Teknik Elektro terdiri atas tiga program studi, antara lain:
#    1. S1 Teknik Elektro (Bachelor of Electrical Engineering)
#    2. S1 Teknologi Informasi (Bachelor of Information Technology)
#    3. S1 Teknik Mekatronika (Bachelor of Mechatronics Engineering)

# %%
#Pelatihan Minggu kedua 1

#Membuat variabel
panjang = 20.5
lebar = 25
tinggi = 10

#Pembuatan operasi
keliling = 2*(panjang+lebar)
luas = panjang*lebar
volume = panjang*lebar*tinggi

#Menampilan output
print('Panjang ='+ str(panjang))
print("Lebar ="+ str(lebar))
print('Tinggi ='+ str(tinggi))
print('Keliling ='+ str(keliling))
print ('Luas ='+ str(luas))
print('Volume ='+ str(volume))
# Out:
# Panjang =20.5
# Lebar =25
# Tinggi =10
# Keliling =91.0
# Luas =512.5
# Volume =5125.0

# %%
#Pelatiham Minggu kedua 2

#Membuat variabel dan operasi hitung
Avg_Shafira = (85+75) /2
N_Hanif_Andi = (75+90) +(70+75)
Avg_N_WiDhHiNe_Kalkulus1= (85+85+80+95)/4
Avg_N_WiDhHiNe_Statistika= (85+85+75+80)/4
Avg_Ntotal_Mhs_Kalkulus1= (85+80+75+95+85+75+70+85+80)/9
Avg_Ntotal_Mhs_Statistika= (75+90+80+80+85+90+75+85+75)/9

#Menampilkan output 1
print ("Output  \n")
print ("Rata-rata nilai Shafira pada kedua mata kuliah = " +str(Avg_Shafira))
print ("Jumlah nilai Hanif dan Andi untuk semua mata kuliah = " +str(N_Hanif_Andi))
print ("Rata-rata nilai Widya, Dhanar, Hikma dan Nedia Kalkulus 1 = " +str(Avg_N_WiDhHiNe_Kalkulus1))
print ("Rata-rata nilai Widya, Dhanar, Hikma dan Nedia Statistika = " +str(Avg_N_WiDhHiNe_Statistika))
print ("Rata-rata nilai mata kuliah Kalkulus 1 = " +str(Avg_Ntotal_Mhs_Kalkulus1))
print ("Rata-rata nilai mata kuliah Metode Statistika = " +str(Avg_Ntotal_Mhs_Statistika))
# Out:
# Output
#
# Rata-rata nilai Shafira pada kedua mata kuliah = 80.0
# Jumlah nilai Hanif dan Andi untuk semua mata kuliah = 310
# Rata-rata nilai Widya, Dhanar, Hikma dan Nedia Kalkulus 1 = 86.25
# Rata-rata nilai Widya, Dhanar, Hikma dan Nedia Statistika = 81.25
# Rata-rata nilai mata kuliah Kalkulus 1 = 81.11111111111111
# Rata-rata nilai mata kuliah Metode Statistika = 81.66666666666667

# %%
#Pelatiham Minggu kedua 3

#Membuat variabel

Krj_thn=10 #tahun
Jam_krj_hari=8 #jam perhari
Hnr_jam=30000 #honor perjamperjam
Ags_hari=31 #jumlah hari kerja bln Agustus
Krj_tdkmsk=3 #jumlah hari tidak masuk kerja
Jam_lembur= 5 #jumlah jam lembur
Hnr_lembur= 10000 #honor lembur perjam


#Membuat operasi

Krj_msk=Ags_hari-Krj_tdkmsk #jumlah hari masuk kerja
Gaji_bln=Jam_krj_hari*Krj_msk*Hnr_jam #jumlah gaji Bulan Agustus
Tunjangan=10/100*Gaji_bln #jumlah tunjangan
Gaji_total=Gaji_bln+(Jam_lembur*Hnr_lembur)


#Menampilkan output

print ("Jumlah gaji Dwi pada bulan Agustus = "+str(Gaji_bln))
print ("Jumlah tunjangan Dwi pada bulan Agustus = "+str(int(Tunjangan)))
print ("Jumlah gaji total Dwi pada bulan Agustus termasuk lembur = "+str(Gaji_total))
# Out:
# Jumlah gaji Dwi pada bulan Agustus = 6720000
# Jumlah tunjangan Dwi pada bulan Agustus = 672000
# Jumlah gaji total Dwi pada bulan Agustus termasuk lembur = 6770000
