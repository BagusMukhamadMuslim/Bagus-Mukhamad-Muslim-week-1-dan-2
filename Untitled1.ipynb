# %%
# Menulis File
with open('/Week3(Bagus).txt', 'w') as file1:
    file1.write("Nama : Bagus Mukhamad Muslim\n")
    file1.write("Program Studi : S1 Teknologi Informasi\n")
    file1.write("NPM : 2420506046\n")
    file1.write("Alamat : Jl. Kyai Mojo, Cacaban, Magelang Tengah\n")
    file1.write("Hobi : Membaca novel\n")
    file1.write("E-mail : muslimbagus625@gmail.com\n")

# %%
# Menampilkan isi File
with open('/Week3(Bagus).txt', 'r') as file1:
    print(file1.read())
# Out:
# Nama : Bagus Mukhamad Muslim
# Program Studi : S1 Teknologi Informasi
# NPM : 2420506046
# Alamat : Jl. Kyai Mojo, Cacaban, Magelang Tengah
# Hobi : Membaca novel
# E-mail : muslimbagus625@gmail.com

# %%
with open("/Week3(Bagus).txt", "r") as file1:
    c = file1.readlines()
    print(c[0])
    print(c[1])
    print(c[5])
# Out:
# Nama : Bagus Mukhamad Muslim
#
# Program Studi : S1 Teknologi Informasi
#
# E-mail : muslimbagus625@gmail.com

# %%
with open('/Week3(Bagus2.1).txt','w') as av:
    av.write(c[0])
    av.write(c[2])
    av.write(c[1])
    av.write(c[3])

# %%
# Menyalin File
with open('/Week3(Bagus).txt','r') as file1:
    with open('/Week3(Bagus2).txt','w') as file2:
      for line in file1:
        file2.write(line)

# %%
item1 = 'Sabun'
item2 = 'Shampo'
item3 = 'Mie instant'
item4 = 'Detergen'
harga1 = 10000
harga2 = 15000
harga3 = 5000
harga4 = 17500
total = harga1+harga2+harga3+harga4

with open('/Kuitansi(Bagus).txt', 'w') as writefile:
        writefile.write('Selamat Datang di Toko MajuJaya\n')
        writefile.write('\n')
        writefile.write('Kuitansi - 4 September 2023\n')
        writefile.write(item1+" = Rp " +str(harga1)+"\n")
        writefile.write(item2+" = Rp " +str(harga2)+"\n")
        writefile.write(item3+" = Rp " +str(harga3)+"\n")
        writefile.write(item4+" = Rp " +str(harga4)+"\n")
        writefile.write(" \n")
        writefile.write("Total Belanja ="+str(int(total))+"\n")

# %%
print ("Selamat datang di Toko Maju Jaya")
print ("Senin, 4 September 2023, 13.05")
print(" ")
print ("DAFTAR BELANJA:")



print(item1,"= Rp"+ str(harga1))
print(item2,"= Rp"+ str(harga2))
print(item3,"= Rp"+ str(harga3))
print(item4,"= Rp"+ str(harga4))

print(" ")
print("Total = Rp"+str(total))
# Out:
# Selamat datang di Toko Maju Jaya
# Senin, 4 September 2023, 13.05
#
# DAFTAR BELANJA:
# Sabun = Rp10000
# Shampo = Rp15000
# Mie instant = Rp5000
# Detergen = Rp17500
#
# Total = Rp47500
